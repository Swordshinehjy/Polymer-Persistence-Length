# %%
import numpy as np
import polymer_pl as pp
unit = {'A': { 'bond': [9.555], 'angle': [], 'rotation': [0] },
    'C': { 'bond': [2.516, 1.443, 2.516], 'angle': [14.8, -14.8],'rotation': [0, 2, 0]},
    'D': {'bond': [2.529, 1.435, 2.529],'angle': [14.8, -14.8],'rotation': [0, 3, 0] },
}
bond = {'AC': 1.453,'AD': 1.457, 'CA': 1.453,'DA': 1.457,}
rotation = {'AC': 1, 'AD': 1,'CA': 1,'DA': 1,}
angle = {'AC': [3.94, 16.5], 'AD': [3.94, 16.5], 'CA': [-16.5, -3.94],'DA': [-16.5, -3.94],}
connection = [['A'], ['C', 'D']]
probability = [[1], [0.5, 0.5]]
aiidt = np.array([[0, 0], [10, 0.55136], [20, 2.36295], [30, 5.5398],
                  [40, 10.13443], [50, 15.93678], [60, 22.55304],
                  [70, 29.06429], [80, 34.44656], [90, 37.20333],
                  [100, 35.96935], [110, 30.6921], [120, 24.54843],
                  [130, 18.48352], [140, 13.25878], [150, 9.18925],
                  [160, 6.3012], [170, 4.69965], [180, 4.25331]])
tt = np.array([[0, 0], [10, -0.05251], [20, 0.07877], [30, 0.84016],
               [40, 2.52048], [50, 5.19849], [60, 8.58539], [70, 12.15607],
               [80, 15.09663], [90, 16.33061], [100, 15.41168],
               [110, 12.75993], [120, 9.58308], [130, 6.66877], [140, 4.46335],
               [150, 3.28188], [160, 3.07184], [170, 3.41315], [180, 3.6757]])
ftft = np.array([[0, 0], [10, 0.35121], [20, 1.31553], [30, 2.58819],
                 [40, 3.94374], [50, 5.27387], [60, 6.59253], [70, 7.8466],
                 [80, 8.84198], [90, 9.30816], [100, 9.05052], [110, 7.88779],
                 [120, 6.29461], [130, 4.90559], [140,
                                                  4.70062], [150, 6.00636],
                 [160, 8.71128], [170, 12.21398], [180, 14.8315]])
labels = {
    1: {'data': aiidt, 'color': 'b', 'label': 'AIID-T' },
    2: {'data': tt, 'color': 'm' , 'label': 'T-T'   },
    3: {'data': ftft, 'color': 'c' , 'label': 'FT-FT' },
}
model = pp.PolymerPersistenceUnit(unit, bond, angle, rotation, connection,
                               probability, 300, labels)

# %%
model.calc_mean_square_end_to_end_distance()
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 10256 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 74256 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 149856 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=8)]: Done 150000 out of 150000 | elapsed:   12.9s finished

# %%
model.calculate_correlation_length_mc()
# Out:
# Generating 150000 copolymer chains...
# Building chain coordinates using 8 parallel jobs...
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 18416 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 82416 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 150000 out of 150000 | elapsed:   12.4s finished
# Chain shape: (150000, 21, 3)
#
# Monte Carlo Result:
# Correlation Length: 10.267152
