# %%
import numpy as np
import matplotlib.pyplot as plt
import polymer_pl as pp

l = np.array([2.502, 1.451])
angle = np.array([14.83, 17.06])
rotation = np.array([0, 1])
labels = {
    1: {'loc': 'MeT-MeT-HeadTail-inv.txt', 'color': 'b'},
    # 2: {'loc': 'PT-PT.txt', 'color': 'm'},
    # 3: {'loc': 'MeT-E.txt', 'color': 'c'},
    # 4: {"label": "TIT-CCNC", "color": 'g'},
    # 5: {"label": "TIT-SCNC", "color": 'r'},
}

# %%
p3mt = pp.PolymerPersistence(l, angle, 700, rotation, labels)
p3mt.report()
# Out:
# -------------- Calculation Report -------------
# Temperature: 700 K
# Max Eigenvalue (lambda_max): 0.889257488765
# Correlation Length: 8.520178
# Persistence Length Geometric (Angstroms): 36.414053
# Persistence Length WLC (Angstroms): 33.897935
# -----------------------------------------------

# %%
p3mt.plot_dihedral_potentials()
