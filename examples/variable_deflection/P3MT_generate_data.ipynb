# %%
import numpy as np
import polymer_pl as pp

temperature = 300  # K

parser = pp.GaussianLogParser('MeT-MeT-HeadTail.LOG')
parser.run()
# Out:
# XYZ successfully generated: MeT-MeT-HeadTail-scan\MeT-MeT-HeadTail.xyz

# %%
calculator = pp.XYZDeflectionAngleCalculator(
    xyz_file_path=r'MeT-MeT-HeadTail-scan\MeT-MeT-HeadTail.xyz',
    atom_indices=[8, 6, 4, 1]
)

calculator.save_csv()
# Out:
# Saved: MeT-MeT-HeadTail-scan\MeT-MeT-HeadTail_deflection_angles.csv
# 'MeT-MeT-HeadTail-scan\\MeT-MeT-HeadTail_deflection_angles.csv'
