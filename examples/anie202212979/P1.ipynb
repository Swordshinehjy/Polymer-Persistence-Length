# %%
import polymer_pl as pp
import scipy.constants as sc
import numpy as np

temperature = 293  # K
# in the original paper kTval=2.43652, 293 K
l = [7.03819,1.46441,7.04499, 1.46458]
Angle = np.array([3.05321,-2.93555, 3.23153,-3.26938])
rotation = np.array([0, 1, 0, 1])
labels = {
    1: {'loc': 'P1.txt', 'color': 'b'},
}

# %%
p1 = pp.PolymerPersistence(l, Angle, temperature, rotation, labels, fittting_method='cosine', cosine_deg=14)
p1.plot_dihedral_potentials()

# %%
p1.plot_correlation_function(n_repeat_units=20,
                                n_samples=150000,
                                start_idx=1,
                                end_idx=10)  # Monte Carlo method
# original paper: 527577
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 150 out of 150 | elapsed:    1.8s finished

# %%
p1.report()  # transfer matrix method
# Out:
# --- Persistence Length Calculation Report ---
# Temperature: 293 K
# Max Eigenvalue (lambda_max): 0.999998109555
# Persistence Length (in repeat units): 528975.619036
# -------------------------------------------
