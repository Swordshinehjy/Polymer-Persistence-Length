# %%
import numpy as np
import polymer_pl as pp

l1 = [9.496, 1.450, 2.497, 1.450, 2.497, 1.450, 9.496, 1.450, 2.497, 1.450, 2.497, 1.450]
l2 = [9.483, 1.450, 2.497, 1.450, 2.497, 1.450, 9.483, 1.450, 2.497, 1.450, 2.497, 1.450]
l3 = [8.702, 1.450, 2.497, 1.450, 2.497, 1.450, 8.702, 1.450, 2.497, 1.450, 2.497, 1.450]
l4 = [8.462, 1.450, 2.497, 1.450, 2.497, 1.450, 8.462, 1.450, 2.497, 1.450, 2.497, 1.450]
Angle1 = np.array([-3.76, 3.76, 17.15, 15.19, -15.19, -17.15, -3.76, 3.76, 17.15, 15.19, -15.19, -17.15])
Angle2 = np.array([6.69, 6.69, 17.15, 15.19, -15.19, -17.15, -6.69, -6.69, -17.15, -15.19, 15.19, 17.15])
Angle3 = np.array([11.12, -11.12, 17.07, 15.19, -15.19, -17.07, 11.12, -11.12, 17.07, 15.19, -15.19, -17.07])
Angle4 = np.array([-17.99, 17.99, 17.08, 15.19, -15.19, -17.08, -17.99, 17.99, 17.08, 15.19, -15.19, -17.08])

# %%
ndt1 = pp.PolymerBackbone(l1, Angle1)
ndt2 = pp.PolymerBackbone(l2, Angle2)
ndt3 = pp.PolymerBackbone(l3, Angle3)
ndt4 = pp.PolymerBackbone(l4, Angle4)
segments = [[0, 1], [2, 5], [6, 7], [8, 11]] # NDT, bithiophene, NDT, bithiophene

# %%
ndt1.report()
ndt1.draw_chain(show_bbox=True)
ndt1.report_angles_segments(segments)
# Out:
# ---- Backbone Calculation Report ----
# Straightness Ratio (Ree/Lc): 0.979000
# <cos(θ)>: 0.972815 ± 0.018123
# <θ>: 0.000000 ± 13.403932 (deg)
# <|θ|>: 12.033333 ± 5.904599 (deg)
# Turn Curvature: -0.000000 ± 0.116787
# Circular Curvature: -0.000000 ± 0.116703
# -------- Minimum Bounding Box Analysis --------
# Box Length/Width: 36.8887 Å / 1.7110 Å
# Box Aspect Ratio (L/W): 21.559917
# -----------------------------------------------
# -- Angles Between Segments and Backbone Orientation --
# Segment 1: -8.82 degrees
# Segment 2: 15.49 degrees
# Segment 3: -8.82 degrees
# Segment 4: 15.49 degrees
# ------------------------------------------------------

# %%
ndt2.report()
ndt2.draw_chain(show_bbox=True)
ndt2.report_angles_segments(segments)
# Out:
# ---- Backbone Calculation Report ----
# Straightness Ratio (Ree/Lc): 0.959130
# <cos(θ)>: 0.971263 ± 0.015986
# <θ>: 0.000000 ± 13.779389 (deg)
# <|θ|>: 13.010000 ± 4.539985 (deg)
# Turn Curvature: 0.000000 ± 0.117232
# Circular Curvature: 0.000000 ± 0.117147
# -------- Minimum Bounding Box Analysis --------
# Box Length/Width: 36.1151 Å / 3.2694 Å
# Box Aspect Ratio (L/W): 11.046252
# -----------------------------------------------
# -- Angles Between Segments and Backbone Orientation --
# Segment 1: -0.00 degrees
# Segment 2: 27.24 degrees
# Segment 3: 0.00 degrees
# Segment 4: -27.24 degrees
# ------------------------------------------------------

# %%
ndt3.report()
ndt3.draw_chain(show_bbox=True)
ndt3.report_angles_segments(segments)
# Out:
# ---- Backbone Calculation Report ----
# Straightness Ratio (Ree/Lc): 0.990444
# <cos(θ)>: 0.967411 ± 0.010453
# <θ>: 0.000000 ± 14.671689 (deg)
# <|θ|>: 14.460000 ± 2.483318 (deg)
# Turn Curvature: 0.000000 ± 0.118351
# Circular Curvature: -0.000000 ± 0.118259
# -------- Minimum Bounding Box Analysis --------
# Box Length/Width: 35.7471 Å / 0.8701 Å
# Box Aspect Ratio (L/W): 41.085500
# -----------------------------------------------
# -- Angles Between Segments and Backbone Orientation --
# Segment 1: -1.54 degrees
# Segment 2: 7.81 degrees
# Segment 3: -1.54 degrees
# Segment 4: 7.81 degrees
# ------------------------------------------------------

# %%
ndt4.report()
ndt4.draw_chain(show_bbox=True)
ndt4.report_angles_segments(segments)
# Out:
# ---- Backbone Calculation Report ----
# Straightness Ratio (Ree/Lc): 0.952048
# <cos(θ)>: 0.957356 ± 0.005789
# <θ>: 0.000000 ± 16.793874 (deg)
# <|θ|>: 16.753333 ± 1.166200 (deg)
# Turn Curvature: 0.000000 ± 0.121889
# Circular Curvature: 0.000000 ± 0.121741
# -------- Minimum Bounding Box Analysis --------
# Box Length/Width: 33.9043 Å / 2.4360 Å
# Box Aspect Ratio (L/W): 13.918100
# -----------------------------------------------
# -- Angles Between Segments and Backbone Orientation --
# Segment 1: -16.73 degrees
# Segment 2: 21.74 degrees
# Segment 3: -16.73 degrees
# Segment 4: 21.74 degrees
# ------------------------------------------------------
